# %% [markdown]
# <a href="https://colab.research.google.com/github/Sof3693/inmersion_datos/blob/main/INMERSION_DATOS_PROYECTO_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inmersión en Datos Proyecto Final

# %% [markdown]
# # Aula 1

# %% [markdown]
# **Carga de Datos**
#
# Importar las bibliotecas necesarias y cargar el conjunto de datos de inmuebles en Bogotá desde un archivo CSV.

# %%
# Montar Google Drive para acceder a los datos
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importar la biblioteca pandas
import pandas as pd

# Cargar el conjunto de datos de inmuebles de Bogotá
inmuebles = pd.read_csv('/content/drive/MyDrive/inmersion_datos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %% [markdown]
# ***Exploración Inicial de Datos***
#
# Exploración inicial de los datos para comprender su estructura y contenido. Algunos incluyeron:
# *   Renombrar columnas para que tengan nombres más descriptivos.
# *   Verificar tipos de datos.
# *   Calcular estadísticas descriptivas básicas.

# %%
# Obtener la forma (número de filas y columnas) del DataFrame
inmuebles.shape
# Out:
# (9520, 8)

# %%
# Mostrar los nombres de las columnas del DataFrame
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
#  Renombrar las columnas 'Baños' y 'Área' a 'Banos' y 'Area' respectivamente
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
# Mostrar una muestra aleatoria de 10 filas del DataFrame después de la modificación de columnas
inmuebles.sample(10)
# Out:
#              Tipo                                    Descripcion  \
# 9060  Apartamento                   Apartamento en venta en Suba
# 8638  Apartamento          Apartamento en venta en Santa Barbara
# 8811         Casa                 Casa en venta en Villa Alsacia
# 3861  Apartamento              Apartamento en venta en Pasadena
# 8829  Apartamento      Apartamento en venta en Chapinero Central
# 9488  Apartamento          Apartamento en venta en Puente Aranda
# 2745  Apartamento     Apartamento en venta en Zona Noroccidental
# 1844  Apartamento                Apartamento en venta en Kennedy
# 1538  Apartamento              Apartamento en venta en Chapinero
# 5406  Apartamento  Apartamento en venta en Ciudadela Colsubsidio
#
#       Habitaciones  Banos  Area                 Barrio  \
# 9060             3      2    63                   Suba
# 8638             1      2    66          Santa Barbara
# 8811             3      2    63          Villa Alsacia
# ...

# %%
# Mostrar información básica sobre el conjunto de datos
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
# Filtrar y mostrar un inmueble específico
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
# Filtrar y mostrar una serie de inmuebles
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
#Realizar operaciones en una columna específica
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
# Obtener el tipo de datos de la columna 'Valor' en las filas desde la 300 hasta la 304
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
# Calcular el promedio del área
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
# Mostrar una muestra aleatoria de 100 filas
inmuebles.sample(100)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 1682         Casa                 Casa en venta en Kennedy             6
# 5931  Apartamento  Apartamento en venta en Chico Reservado             2
# 449          Casa          Casa en venta en Barrios Unidos             3
# 83    Apartamento          Apartamento en venta en Kennedy             2
# 6239  Apartamento          Apartamento en venta en Usaquén             2
# ...           ...                                      ...           ...
# 5062  Apartamento      Apartamento en venta en Los Rosales             3
# 8185  Apartamento   Apartamento en venta en Barrios Unidos             3
# 5579  Apartamento    Apartamento en venta en Santa Barbara             2
# 5557  Apartamento   Apartamento en venta en Barrios Unidos             3
# 8988  Apartamento         Apartamento en venta en Cedritos             1
#
#       Banos  Area           Barrio                                    UPZ  \
# ...

# %%
#Busca propiedades ubicadas en el barrio llamado "Chico Reservado".
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
# Contar cuántas propiedades se encuentran en el barrio 'Chico Reservado'
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
#Crea una variable llamada 'inmuebles_chico'
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
# Obtener el tipo de datos
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
#Crear un nuevo DataFrame 'chico_reservado' que contiene solo las propiedades en el barrio 'Chico Reservado'
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
# Calcular el promedio del área de las propiedades en el barrio 'Chico Reservado'
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
# Calcular el promedio del área de todas las propiedades
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
# Obtener la cantidad de barrios únicos
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
# Mostrar la cantidad de propiedades en cada barrio
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
# Obtener la cantidad de UPZ
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
# Mostrar la cantidad de propiedades en cada UPZ en forma de gráfico de barras
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
# Mostrar las 10 UPZ con la mayor cantidad de propiedades en forma de gráfico de barras
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ## **Desafío 1**

# %% [markdown]
# 1. Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.

# %%
#Este código calcula el promedio del tamaño (área) de los inmuebles para cada barrio en el conjunto de datos.
promedio_por_barrio = inmuebles.groupby('Barrio')['Area'].mean()

# %%
#Crea una lista de los 10 barrios con los mayores promedios de tamaño (área) de inmuebles
top_10_barrios = promedio_por_barrio.sort_values(ascending=False).head(10)

# %%
print("Promedio de área de los inmuebles en los 10 barrios principales:")
print(top_10_barrios)
# Out:
# Promedio de área de los inmuebles en los 10 barrios principales:
# Barrio
# Modelia                  4316.750000
# Libertador                642.000000
# Bosa Piamonte             400.000000
# La Soledad                378.625000
# Restrepo                  336.500000
# Santa Librada             328.000000
# Las Ferias                320.000000
# Santa Ana                 309.375000
# Veraguas                  302.666667
# Bellavista Occidental     286.200000
# Name: Area, dtype: float64

# %% [markdown]
# 2. Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %%
#Cuenta cuántos inmuebles hay en cada barrio
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
#calcula la mediana de los valores de área
inmuebles.Area.median()
# Out:
# 80.0

# %%
#Calcula el valor mínimo del área
inmuebles.Area.min()
# Out:
# 2

# %%
#Calcula el valor máximo del área
inmuebles.Area.max()
# Out:
# 166243

# %% [markdown]
# #**Aula 2**

# %%
# Mostrar una muestra aleatoria de 5 filas del DataFrame 'inmuebles'
inmuebles.sample(5)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 4188  Apartamento  Apartamento en venta en Ciudad Salitre             3
# 4363  Apartamento       Apartamento en venta en Chapinero             2
# 4439  Apartamento    Apartamento en venta en Gran America             2
# 7548  Apartamento         Apartamento en venta en Kennedy             4
# 1325  Apartamento      Apartamento en venta en Costa Azul             2
#
#       Banos  Area          Barrio                                 UPZ  \
# 4188      2    80  Ciudad Salitre             Ciudad Salitre Oriental
# 4363      3   130       Chapinero  CHAPINERO: Pardo Rubio + Chapinero
# 4439      2    35    Gran America                      Quinta Paredes
# 7548      2    53         Kennedy                     Kennedy Central
# 1325      2    44      Costa Azul                                Suba
#
#               Valor
# 4188  $ 680.000.000
# 4363  $ 900.000.000
# 4439  $ 250.000.000
# 7548  $ 165.000.000
# ...

# %%
# Obtener información sobre el DataFrame 'inmuebles'
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
# Obtener el tipo de datos de la columna 'Valor'
type(inmuebles.Valor[0])
# Out:
# str

# %%
#Realizar una operación de suma en las primeras 5 filas de la columna 'Valor'
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
#Divide el primer valor de la columna "Valor" en palabras separadas por espacios.
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
# Separar la columna 'Valor' en dos columnas 'Moneda' y 'Precio' usando el espacio como separador
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
# Mostrar una muestra aleatoria de 3 filas
inmuebles.sample(3)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 1202  Apartamento         Apartamento en venta en Usaquén             4
# 4534  Apartamento  Apartamento en venta en Barrios Unidos             1
# 2268  Apartamento       Apartamento en venta en Pasadena              1
#
#       Banos  Area          Barrio        UPZ          Valor Moneda  \
# 1202      4   121         Usaquén    Usaquén  $ 620.000.000      $
# 4534      1    31  Barrios Unidos  Los Andes  $ 185.000.000      $
# 2268      2    49       Pasadena         NaN  $ 340.000.000      $
#
#            Precio
# 1202  620.000.000
# 4534  185.000.000
# 2268  340.000.000

# %%
# Obtener información sobre 'inmuebles' después de agregar las columnas 'Moneda' y 'Precio'
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
# Calcular la suma de la columna 'Precio'
inmuebles['Precio'].sum()
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.0
# ...

# %%
# Eliminar los puntos en la columna 'Precio' para convertirla a tipo float
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)

# %%
# Mostrar las columnas 'Precio' y 'Barrio' del DataFrame
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
# Obtener información sobre el DataFrame 'inmuebles' después de convertir la columna 'Precio' a tipo float
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
# Crear una nueva columna 'Precio_Millon' que representa el precio en millones de la propiedad
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
# Obtener información
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
# Calcular estadísticas descriptivas sobre las columnas numéricas
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
# Configurar el formato de visualización para mostrar dos decimales en los resultados
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
# Localizar las filas donde el número de habitaciones es igual a 110
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
# Localizar las filas donde el área es igual a 2
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
# Crear un histograma de la columna 'Precio_Millon' con 10 bins
inmuebles['Precio_Millon'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Importar las bibliotecas matplotlib y seaborn para realizar visualizaciones
import matplotlib.pyplot as plt
import seaborn as sns

# Configurar el tamaño de la figura
plt.figure(figsize=(10,6))
# Crear un histograma con densidad de probabilidad (KDE) de la columna 'Precio_Millon' y dividir por tipo de propiedad
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
# Configurar el título y los ejes del gráfico
grafica.set_title('Distribución de Valores de los inmuebles en Bogotá')
plt.xlim((50,1000))
# Guardar la gráfica como una imagen
plt.savefig('/content/drive/MyDrive/inmersion_datos/valor_inmuebles.png',format='png')
# Mostrar la gráfica
plt.show()

# %% [markdown]
# ## **Desafío 2**

# %% [markdown]
# ***1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información)***

# %%
#Este código crea un gráfico que muestra la distribución de los valores de inmuebles en Bogotá, dividiendo los inmuebles en tres tipos: "Apartamento", "Casa" y "Local".
import matplotlib.pyplot as plt
import seaborn as sns

tipos_seleccionados = ['Apartamento', 'Casa', 'Local']

inmuebles_seleccionados = inmuebles[inmuebles['Tipo'].isin(tipos_seleccionados)]

plt.figure(figsize=(12, 6))
grafica = sns.histplot(data=inmuebles_seleccionados, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribución de Valores de Inmuebles en Bogotá por Tipo')
plt.xlim((50, 1000))
plt.xlabel('Precio en Millones')
plt.ylabel('Densidad de Probabilidad')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('/content/drive/MyDrive/inmersion_datos/valor_inmuebles_refinado.png', format='png')
plt.show()

# %% [markdown]
# ***2. Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.***

# %%
# calcula el precio por metro cuadrado (m²) para cada inmueble en Bogotá y lo almacena en una nueva columna llamada 'Precio_m2_Millon'. Luego, crea un gráfico de barras que muestra el precio promedio del metro cuadrado por barrio en la ciudad.
inmuebles['Precio_m2_Millon'] = inmuebles['Precio_Millon'] / inmuebles['Area']

plt.figure(figsize=(24, 8))
sns.barplot(data=inmuebles, x='Barrio', y='Precio_m2_Millon', palette='viridis')
plt.title('Precio del m² por Barrio')
plt.xlabel('Barrio')
plt.ylabel('Precio del m² (Millones)')
plt.xticks(rotation=90)
plt.savefig('/content/drive/MyDrive/inmersion_datos/precio_m2_barrio.png', format='png')
plt.show()

# %% [markdown]
# #**Aula 3**

# %%
# Calcular el valor por metro cuadrado (m²) y agregarlo como una nueva columna 'Valor_m2_Millon'
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Precio_m2_Millon  \
# 0    $ 360.000.000      $   360000000         360.00              5.14
# 1    $ 670.000.000      $   670000000         670.00              3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00              7.78
#
#    Valor_m2_Millon
# 0             5.14
# 1             3.94
# 2             7.78

# %%
#Calcula estadísticas promedio para las columnas numéricas agrupadas por barrio en el DataFrame 'inmuebles'.
inmuebles.groupby('Barrio').mean()
# Out:
# <ipython-input-57-c8f3c00fe360>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   inmuebles.groupby('Barrio').mean()
#                     Habitaciones  Banos   Area  Precio_Millon  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00
# Alhambra                    3.00   2.94 190.41         752.35
# Andes Norte                 3.00   2.86 124.86         709.57
# Antonio Nariño              4.31   2.50 163.06         459.22
# Barrancas                   2.87   2.13  70.20         314.13
# ...                          ...    ...    ...            ...
# Villa Maria                 4.69   3.69 207.15         402.85
# Villas De Granada           3.45   2.32  86.59         282.30
# Villemar                    2.94   2.06  76.89         303.83
# ...

# %%
# Crear un DataFrame 'datos_barrio' con información agregada por barrio
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
# <ipython-input-58-623b9cad1cab>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datos_barrio = inmuebles.groupby('Barrio').sum()
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# ...

# %%
# Calcular el valor promedio del valor por metro cuadrado por barrio en 'datos_barrio'
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Precio_m2_Millon  Valor_m2_Millon  Valor_m2_Barrio
# Barrio
# Alameda                         5.98             5.98             5.98
# ...

# %%
# Crear un diccionario 'm2_barrio' para mapear los valores promedio por barrio al DataFrame original
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
#Se asignan valores de precio por metro cuadrado a cada inmueble según su barrio y se muestra el resultado.
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Precio_m2_Millon  \
# ...

# %%
#Se obtienen los 10 barrios más comunes en el conjunto de datos de inmuebles.
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
#Reinicia el índice del DataFrame "datos_barrio" y sobrescribe el DataFrame original con este nuevo índice reiniciado.
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Precio_m2_Millon  Valor_m2_Millon  Valor_m2_Barrio
# 0                5.98             5.98             5.98
# ...

# %%
#Filtra datos de "datos_barrio" para mostrar solo los 10 barrios principales.
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Precio_m2_Millon  Valor_m2_Millon  Valor_m2_Barrio
# 5             2070.61          2070.61             2.96
# 10            1654.36          1654.36             2.68
# ...

# %%
#Genera un gráfico de barras para los 10 barrios principaleS
plt.figure(figsize=(10,8))
ax = sns.barplot(x="Barrio", y="Valor_m2_Barrio", data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)

# %%
#Crea un gráfico de caja (boxplot) para los 10 barrios principales
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
#crea un gráfico de caja que muestra la distribución de los valores por metro cuadrado en millones en los 10 barrios principales. Excluye valores por metro cuadrado mayores a 15 millones para una mejor visualización
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
#crea un gráfico de caja que muestra la distribución del área de los inmuebles en los 10 barrios principales, excluyendo aquellos con un área superior a 500 metros cuadrados para una mejor visualización.
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Area", data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
#crea un gráfico de caja que muestra la distribución de los precios de los inmuebles en los 10 barrios principales, excluyendo aquellos con un precio superior a 2000 millones de pesos.
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_Millon", data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
#Este código utiliza Pandas para leer un archivo CSV, con separador ';' y codificación 'latin-1', luego muestra las primeras filas del archivo.
datos_raw = pd.read_csv('/content/drive/MyDrive/inmersion_datos/Identificación (Capítulo A).csv', sep = ';',encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
#Devuelve número de filas y columnas
datos_raw.shape
# Out:
# (106467, 11)

# %%
#Filtra datos en el DataFrame para mantener solo registros asociados con el código '11001' en la columna 'MPIO'. Luego, muestra la forma del DataFrame resultante para mostrar cuántos registros quedan después de la filtración.

datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
# leen varios archivos CSV (datos de diferentes capítulos) desde ubicaciones específicas y almacenan los datos en diferentes DataFrames
datos_b = pd.read_csv('/content/drive/MyDrive/inmersion_datos/Datos de la vivenda y su entorno (Capítulo B).csv',sep=';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/inmersion_datos/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/inmersion_datos/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/inmersion_datos/Educación (Capitulo H).csv',sep=';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/inmersion_datos/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/inmersion_datos/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')
# Out:
# <ipython-input-73-71ab354de76b>:3: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/inmersion_datos/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
# <ipython-input-73-71ab354de76b>:4: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/inmersion_datos/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
# <ipython-input-73-71ab354de76b>:5: DtypeWarning: Columns (26,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/inmersion_datos/Educación (Capitulo H).csv',sep=';',encoding='latin-1')
# ...

# %%
#Se unen dos DataFrames por la columna "DIRECTORIO" usando left join.
datos_dane = pd.merge(datos_raw,datos_b,on='DIRECTORIO', how='left')
#Devuelve número de filas y columnas
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# Out:
# <ipython-input-76-94d5bdd5b9a5>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')

# %%
#Devuelve número de filas y columnas
datos_dane.shape
# Out:
# (238559, 281)

# %%
#Muestra la información básica sobre el DataFrame
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# ## **Desafío 3**
#
# 1. Dar un vistazo a la base de datos del DANE, entender estas variables conceptualmente para entender mejor el contexto de esta base.
# 2.  Organizar tu notebook para que tu proyecto quede mejor presentado.

# %% [markdown]
# #**Aula 4**

# %%
#Se carga un archivo CSV llamado 'datos_dane.csv' en un DataFrame llamado datos_dane.
datos_dane = pd.read_csv('/content/drive/MyDrive/inmersion_datos/datos_dane.csv')
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane.shape
# Out:
# (9857, 55)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %%
#Renombra las columnas del DataFrame datos_dane utilizando un diccionario llamado dic_dane para hacer que los nombres de las columnas sean más legibles.
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO',
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES',
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES',
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA',
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19',
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA',
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO',
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA',
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO',
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO',
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %%
#Calcula la media de las columnas seleccionadas en el DataFrame datos_dane agrupado por el estrato utilizando el método groupby.
datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %%
#Crea un nuevo DataFrame llamado 'datos' a partir de una selección de columnas del DataFrame original 'datos_dane'.
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %%
# filtra el DataFrame 'datos' para mostrar solo las filas en las que el valor de la columna 'NOMBRE_ESTRATO' sea igual a '20 de Julio'.
datos.loc[datos.NOMBRE_ESTRATO == '20 de Julio']
# Out:
#      NOMBRE_ESTRATO  CONJUNTO_CERRADO  INSEGURIDAD  TERMINALES_BUS  \
# 513     20 de Julio                 0            0               0
# 706     20 de Julio                 0            1               0
# 707     20 de Julio                 0            1               0
# 708     20 de Julio                 0            1               0
# 709     20 de Julio                 0            1               0
# ...             ...               ...          ...             ...
# 8372    20 de Julio                 0            1               0
# 8751    20 de Julio                 0            0               0
# 8752    20 de Julio                 0            1               0
# 8783    20 de Julio                 0            1               1
# 9287    20 de Julio                 0            1               0
#
#       BARES_DISCO  RUIDO  OSCURO_PELIGROSO  SALARIO_MES  TIENE_ESCRITURA  \
# 513             0      1                 0        98.00             1.00
# ...

# %%
#El código calcula el promedio de varias variables para cada estrato en el DataFrame 'datos' y almacena estos promedios en un nuevo DataFrame llamado 'datos_tratados'.
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %%
#Fusiona dos DataFrames ('inmuebles' y 'datos_tratados') usando la columna 'UPZ' de 'inmuebles' y 'NOMBRE_ESTRATO' de 'datos_tratados' como clave de unión. El tipo de fusión es 'left', conservando todas las filas de 'inmuebles'
pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
# Fusiona los DataFrames 'inmuebles' y 'datos_tratados' utilizando las columnas 'UPZ' de 'inmuebles' y 'NOMBRE_ESTRATO' de 'datos_tratados' como clave de unión.
datos_ml = pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millon             9520 non-null   float64
#  11  Precio_m2_Millon          9520 non-null   float64
#  12  Valor_m2_Millon           9520 non-null   float64
# ...

# %%
#Cargando datos UPZ y fusionándolos con datos inmobiliarios.
upz = pd.read_csv('/content/drive/MyDrive/inmersion_datos/cod_upz.csv')
datos_ml = pd.merge(datos_ml,upz,left_on='UPZ',right_on='NOMBRE_ESTRATO', how='inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  BARES_DISCO  RUIDO  \
# ...

# %%
datos_ml.shape
# Out:
# (9318, 27)

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millon             9318 non-null   float64
#  11  Precio_m2_Millon          9318 non-null   float64
#  12  Valor_m2_Millon           9318 non-null   float64
# ...

# %%
#Visualización de la distribución de los precios de los inmuebles.
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, y = 'Precio_Millon')
plt.show()

# %%
#Filtrando inmuebles con precios anómalos.
datos_ml.query('Precio_Millon > 5000 | Precio_Millon < 60')
# Out:
#                      Tipo                                  Descripcion  \
# 207           Apartamento            Apartamento en venta en Chapinero
# 323                 Local                  Local en venta en Chapinero
# 702                  Casa                   Casa en venta en Chapinero
# 708                  Casa                   Casa en venta en Chapinero
# 829           Apartamento   Apartamento en venta en Zona Noroccidental
# 1371          Apartamento             Apartamento en venta en El Chicó
# 1414          Apartamento             Apartamento en venta en El Chicó
# 1429                Local             Local en venta en Quinta Camacho
# 1442                Local             Local en venta en Quinta Camacho
# 1518          Apartamento      Apartamento en venta en Chico Reservado
# 1532          Apartamento          Apartamento en venta en Chico Norte
# 1533          Apartamento          Apartamento en venta en Los Rosales
# ...

# %%
#Eliminando inmuebles con precios extremadamente bajos o altos.
datos_ml = datos_ml.query('Precio_Millon < 1200 & Precio_Millon > 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
#Visualizando la distribución de precios de los inmuebles después de filtrar los valores extremos.
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, y = 'Precio_Millon')
plt.show()

# %%
#Crea una nueva columna llamada "SALARIO_ANUAL_MI" en el DataFrame datos_ml calculando el salario anual en millones de pesos.
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# 0      48.42
# 1      48.42
# 3      48.42
# 9      48.42
# 10     48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 8313, dtype: float64

# %%
#Gráfico de dispersión que muestra la relación entre el salario anual en millones de pesos (MI) y el valor por metro cuadrado en millones de pesos (Millon).
plt.figure(figsize=(10,8))
sns.scatterplot(data=datos_ml, x='SALARIO_ANUAL_MI',y ='Valor_m2_Millon')
plt.ylim((0,15))
plt.show()

# %%
#Calcula la correlación entre todas las columnas numéricas del DataFrame datos_ml utilizando el método corr() y muestra la correlación en un mapa de calor.
datos_ml.corr()
# Out:
# <ipython-input-99-0a8319398da9>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datos_ml.corr()
#                           Habitaciones  Banos  Area  Precio_Millon  \
# Habitaciones                      1.00   0.44  0.03           0.18
# Banos                             0.44   1.00  0.04           0.66
# Area                              0.03   0.04  1.00           0.04
# Precio_Millon                     0.18   0.66  0.04           1.00
# Precio_m2_Millon                 -0.31  -0.03 -0.04           0.36
# Valor_m2_Millon                  -0.31  -0.03 -0.04           0.36
# Valor_m2_Barrio                  -0.21   0.13 -0.04           0.40
# CONJUNTO_CERRADO                 -0.12   0.16 -0.01           0.32
# INSEGURIDAD                       0.13  -0.19 -0.00          -0.37
# ...

# %%
# Mapa de calor que muestra las relaciones entre las variables en el conjunto de datos, indicando la fuerza y dirección de la correlación.
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);
# Out:
# <ipython-input-100-ddfaef8f2048>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')

# %%
#preparando los datos para entrenar un modelo que intentará predecir los precios de los inmuebles en Bogotá. Se divide el conjunto de datos en dos partes, una para enseñar al modelo (entrenamiento) y otra para ver cuán bien funciona (prueba).
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = datos_ml[['COD_UPZ_GRUPO']]
y = datos_ml['Precio_Millon']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=99)

# %%
#Se utilizan para enseñar al modelo a hacer predicciones sobre los precios de los inmuebles.
X_train
# Out:
#       COD_UPZ_GRUPO
# 1512         817.00
# 7864          85.00
# 6058          21.00
# 1683         817.00
# 2481          14.00
# ...             ...
# 6038          21.00
# 8875         102.00
# 2200          14.00
# 3883         803.00
# 8154          85.00
#
# [6234 rows x 1 columns]

# %%
#Se utilizan para evaluar el rendimiento del modelo y hacer predicciones sobre los precios de los inmuebles que no se usaron durante el entrenamiento.
X_test
# Out:
#       COD_UPZ_GRUPO
# 6340          74.00
# 7805          85.00
# 4902          47.00
# 7041         100.00
# 2436          14.00
# ...             ...
# 3323          14.00
# 3945         803.00
# 5572          27.00
# 3633         803.00
# 3652         803.00
#
# [2079 rows x 1 columns]

# %%
#Predicciones precisas sobre los precios de los inmuebles.
y_train
# Out:
# 1512   1050.00
# 7864    129.00
# 6058    206.38
# 1683    650.00
# 2481    250.00
#          ...
# 6038    560.00
# 8875    560.00
# 2200    685.00
# 3883    850.00
# 8154    132.00
# Name: Precio_Millon, Length: 6234, dtype: float64

# %%
#Crea un modelo de regresión lineal (LinearRegression) y ajusta el modelo utilizando los datos de entrenamiento.
modelo = LinearRegression()

# %%
#inicia el proceso de entrenamiento del modelo de regresión lineal para que pueda hacer predicciones precisas sobre los precios de los inmuebles en función de las características proporcionadas.
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#calcula las predicciones del modelo de regresión lineal para los datos de prueba y almacena esas predicciones en la variable y_predict_test.
y_predict_test = modelo.predict(X_test)

# %%
#calculan dos métricas comunes para evaluar el rendimiento de un modelo de regresión, en este caso, el modelo de regresión lineal.
from sklearn.metrics import mean_absolute_error, r2_score

baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_r2 = r2_score(y_test, y_predict_test)
#Los resultados de estas métricas se imprimen en la consola utilizando print()
print(baseline_mae,baseline_r2)
# Out:
# 187.323609443345 0.031111799984413713

# %%
from sklearn.metrics import mean_absolute_error, r2_score

baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_r2 = r2_score(y_test, y_predict_test)
print(baseline_mae,baseline_r2)
# Out:
# 187.323609443345 0.031111799984413713

# %%
#calculando dos métricas para evaluar el rendimiento de un modelo de regresión linea
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']]

y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988

# %%
#se encarga de construir un modelo que intenta predecir el precio de los inmuebles en función de algunas características como el número de habitaciones, baños, si está en un conjunto cerrado, el salario anual de las personas y si tienen escritura del inmueble.
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']]

y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988

# %%
#se utiliza para hacer una predicción de precio utilizando el modelo de regresión lineal entrenado anteriormente.Los números dentro de la lista [816, 3, 2, 1, 50, 1] representan valores para diferentes características de un inmueble
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([434.21129691])
